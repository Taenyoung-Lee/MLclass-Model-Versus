# %% [markdown]
# LSTM model에 따른 gradient problem observation
#
# input_size, output_size 1로 고정시키고
# batch_size, hidden_size, sequence_length를 점진적으로 변화.
# 이 때 계산의 복잡성이 너무 커지는것 및 의미있는 모델 유지를 위해 Validation Set에 대한 Error를 기준으로 epochs수 조정(Early Stopping 활용)

# %%
import torch
import torch.nn as nn
import numpy as np


class SimpleLSTM(nn.Module):
    def __init__(self, input_size, hidden_size, output_size):
        super(SimpleLSTM, self).__init__()
        self.lstm = nn.LSTM(input_size, hidden_size)
        self.linear = nn.Linear(hidden_size, output_size)

    def forward(self, x):
        output, _ = self.lstm(x)
        output = self.linear(output[-1])
        return output
    

def early_stopping(validation_losses, patience):
    if len(validation_losses) > patience and validation_losses[-1] > min(validation_losses[-patience:-1]):
        return True
    return False

input_size = 1
output_size = 1
# 변화
batch_sizes = list(range(16,512,10)) # 배치 크기 범위
hidden_sizes = list(range(10,100,10))  # 은닉 상태 크기 범위
max_seq_length = 1000  # 최대 시퀀스 길이 설정
seq_length_increment = 50  # 시퀀스 길이 증가 간격


patience = 3


max_gradient_norm = 100.0  # 그라디언트 폭발 임계값
min_gradient_norm = 0.001  # 그라디언트 소실 임계값


experiment_results = {}


for batch_size in batch_sizes:
    for hidden_size in hidden_sizes:
        seq_length = 50
        while seq_length <= max_seq_length:
            
            data_x = torch.randn(seq_length, batch_size, input_size)
            data_y = torch.randn(batch_size, output_size)
            split_idx = int(batch_size * 0.8) 
            train_x, val_x = data_x[:, :split_idx, :], data_x[:, split_idx:, :]
            train_y, val_y = data_y[:split_idx, :], data_y[split_idx:, :]

            
            model = SimpleLSTM(input_size, hidden_size, output_size)
            loss_function = nn.MSELoss()
            optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

            validation_losses = []
            for epoch in range(50):  
                
                model.train()
                optimizer.zero_grad()
                train_output = model(train_x)
                train_loss = loss_function(train_output, train_y)
                train_loss.backward()
                optimizer.step()

                
                model.eval()
                with torch.no_grad():
                    val_output = model(val_x)
                    val_loss = loss_function(val_output, val_y)
                validation_losses.append(val_loss.item())

                
                if early_stopping(validation_losses, patience):
                    break

            
            gradients = np.array([p.grad.norm().item() for p in model.parameters() if p.grad is not None])
            if np.any(gradients > max_gradient_norm) or np.any(gradients < min_gradient_norm):
                experiment_results[(batch_size, hidden_size, seq_length)] = "Gradient Problem Detected"
                break
            else:
                experiment_results[(batch_size, hidden_size, seq_length)] = "No Problem"
                seq_length += seq_length_increment


experiment_results
# Out:
# {(16, 10, 50): 'No Problem',
#  (16, 10, 100): 'No Problem',
#  (16, 10, 150): 'No Problem',
#  (16, 10, 200): 'No Problem',
#  (16, 10, 250): 'No Problem',
#  (16, 10, 300): 'No Problem',
#  (16, 10, 350): 'No Problem',
#  (16, 10, 400): 'No Problem',
#  (16, 10, 450): 'No Problem',
#  (16, 10, 500): 'No Problem',
#  (16, 10, 550): 'No Problem',
#  (16, 10, 600): 'No Problem',
#  (16, 10, 650): 'No Problem',
#  (16, 10, 700): 'No Problem',
#  (16, 10, 750): 'No Problem',
#  (16, 10, 800): 'No Problem',
#  (16, 10, 850): 'No Problem',
#  (16, 10, 900): 'No Problem',
#  (16, 10, 950): 'Gradient Problem Detected',
#  (16, 20, 50): 'No Problem',
#  (16, 20, 100): 'No Problem',
#  (16, 20, 150): 'No Problem',
#  (16, 20, 200): 'No Problem',
#  (16, 20, 250): 'No Problem',
#  (16, 20, 300): 'No Problem',
#  (16, 20, 350): 'No Problem',
#  (16, 20, 400): 'No Problem',
#  (16, 20, 450): 'No Problem',
#  (16, 20, 500): 'No Problem',
#  (16, 20, 550): 'No Problem',
#  (16, 20, 600): 'No Problem',
#  (16, 20, 650): 'No Problem',
#  (16, 20, 700): 'No Problem',
#  (16, 20, 750): 'No Problem',
#  (16, 20, 800): 'No Problem',
#  (16, 20, 850): 'No Problem',
#  (16, 20, 900): 'No Problem',
#  (16, 20, 950): 'No Problem',
#  (16, 20, 1000): 'No Problem',
#  (16, 30, 50): 'No Problem',
#  (16, 30, 100): 'No Problem',
#  (16, 30, 150): 'No Problem',
#  (16, 30, 200): 'No Problem',
#  (16, 30, 250): 'No Problem',
#  (16, 30, 300): 'No Problem',
#  (16, 30, 350): 'No Problem',
#  (16, 30, 400): 'No Problem',
#  (16, 30, 450): 'No Problem',
#  (16, 30, 500): 'No Problem',
#  (16, 30, 550): 'No Problem',
#  (16, 30, 600): 'No Problem',
#  (16, 30, 650): 'No Problem',
#  (16, 30, 700): 'No Problem',
#  (16, 30, 750): 'No Problem',
#  (16, 30, 800): 'No Problem',
#  (16, 30, 850): 'No Problem',
#  (16, 30, 900): 'No Problem',
#  (16, 30, 950): 'No Problem',
#  (16, 30, 1000): 'No Problem',
#  (16, 40, 50): 'No Problem',
#  (16, 40, 100): 'No Problem',
#  (16, 40, 150): 'No Problem',
#  (16, 40, 200): 'No Problem',
#  (16, 40, 250): 'No Problem',
#  (16, 40, 300): 'No Problem',
#  (16, 40, 350): 'No Problem',
#  (16, 40, 400): 'No Problem',
#  (16, 40, 450): 'No Problem',
#  (16, 40, 500): 'No Problem',
#  (16, 40, 550): 'No Problem',
#  (16, 40, 600): 'No Problem',
#  (16, 40, 650): 'No Problem',
#  (16, 40, 700): 'No Problem',
#  (16, 40, 750): 'No Problem',
#  (16, 40, 800): 'No Problem',
#  (16, 40, 850): 'No Problem',
#  (16, 40, 900): 'No Problem',
#  (16, 40, 950): 'No Problem',
#  (16, 40, 1000): 'No Problem',
#  (16, 50, 50): 'No Problem',
#  (16, 50, 100): 'No Problem',
#  (16, 50, 150): 'No Problem',
#  (16, 50, 200): 'No Problem',
#  (16, 50, 250): 'No Problem',
#  (16, 50, 300): 'No Problem',
#  (16, 50, 350): 'No Problem',
#  (16, 50, 400): 'No Problem',
#  (16, 50, 450): 'No Problem',
#  (16, 50, 500): 'No Problem',
#  (16, 50, 550): 'No Problem',
#  (16, 50, 600): 'No Problem',
#  (16, 50, 650): 'No Problem',
#  (16, 50, 700): 'No Problem',
#  (16, 50, 750): 'No Problem',
#  (16, 50, 800): 'No Problem',
#  (16, 50, 850): 'No Problem',
#  (16, 50, 900): 'No Problem',
#  (16, 50, 950): 'No Problem',
#  (16, 50, 1000): 'No Problem',
#  (16, 60, 50): 'No Problem',
#  (16, 60, 100): 'No Problem',
#  (16, 60, 150): 'No Problem',
#  (16, 60, 200): 'No Problem',
#  (16, 60, 250): 'No Problem',
#  (16, 60, 300): 'No Problem',
#  (16, 60, 350): 'No Problem',
#  (16, 60, 400): 'No Problem',
#  (16, 60, 450): 'No Problem',
#  (16, 60, 500): 'No Problem',
#  (16, 60, 550): 'No Problem',
#  (16, 60, 600): 'No Problem',
#  (16, 60, 650): 'No Problem',
#  (16, 60, 700): 'No Problem',
#  (16, 60, 750): 'No Problem',
#  (16, 60, 800): 'No Problem',
#  (16, 60, 850): 'No Problem',
#  (16, 60, 900): 'No Problem',
#  (16, 60, 950): 'No Problem',
#  (16, 60, 1000): 'No Problem',
#  (16, 70, 50): 'No Problem',
#  (16, 70, 100): 'No Problem',
#  (16, 70, 150): 'No Problem',
#  (16, 70, 200): 'No Problem',
#  (16, 70, 250): 'No Problem',
#  (16, 70, 300): 'No Problem',
#  (16, 70, 350): 'No Problem',
#  (16, 70, 400): 'No Problem',
#  (16, 70, 450): 'No Problem',
#  (16, 70, 500): 'No Problem',
#  (16, 70, 550): 'No Problem',
#  (16, 70, 600): 'No Problem',
#  (16, 70, 650): 'No Problem',
#  (16, 70, 700): 'No Problem',
#  (16, 70, 750): 'No Problem',
#  (16, 70, 800): 'No Problem',
#  (16, 70, 850): 'No Problem',
#  (16, 70, 900): 'No Problem',
#  (16, 70, 950): 'No Problem',
#  (16, 70, 1000): 'No Problem',
#  (16, 80, 50): 'No Problem',
#  (16, 80, 100): 'No Problem',
#  (16, 80, 150): 'No Problem',
#  (16, 80, 200): 'No Problem',
#  (16, 80, 250): 'No Problem',
#  (16, 80, 300): 'No Problem',
#  (16, 80, 350): 'No Problem',
#  (16, 80, 400): 'No Problem',
#  (16, 80, 450): 'No Problem',
#  (16, 80, 500): 'No Problem',
#  (16, 80, 550): 'No Problem',
#  (16, 80, 600): 'No Problem',
#  (16, 80, 650): 'No Problem',
#  (16, 80, 700): 'No Problem',
#  (16, 80, 750): 'No Problem',
#  (16, 80, 800): 'No Problem',
#  (16, 80, 850): 'No Problem',
#  (16, 80, 900): 'No Problem',
#  (16, 80, 950): 'No Problem',
#  (16, 80, 1000): 'No Problem',
#  (16, 90, 50): 'No Problem',
#  (16, 90, 100): 'No Problem',
#  (16, 90, 150): 'No Problem',
#  (16, 90, 200): 'No Problem',
#  (16, 90, 250): 'No Problem',
#  (16, 90, 300): 'No Problem',
#  (16, 90, 350): 'No Problem',
#  (16, 90, 400): 'No Problem',
#  (16, 90, 450): 'No Problem',
#  (16, 90, 500): 'No Problem',
#  (16, 90, 550): 'No Problem',
#  (16, 90, 600): 'No Problem',
#  (16, 90, 650): 'No Problem',
#  (16, 90, 700): 'No Problem',
#  (16, 90, 750): 'No Problem',
#  (16, 90, 800): 'No Problem',
#  (16, 90, 850): 'No Problem',
#  (16, 90, 900): 'No Problem',
#  (16, 90, 950): 'No Problem',
#  (16, 90, 1000): 'No Problem',
#  (26, 10, 50): 'No Problem',
#  (26, 10, 100): 'No Problem',
#  (26, 10, 150): 'No Problem',
#  (26, 10, 200): 'No Problem',
#  (26, 10, 250): 'No Problem',
#  (26, 10, 300): 'No Problem',
#  (26, 10, 350): 'No Problem',
#  (26, 10, 400): 'No Problem',
#  (26, 10, 450): 'No Problem',
#  (26, 10, 500): 'No Problem',
#  (26, 10, 550): 'No Problem',
#  (26, 10, 600): 'No Problem',
#  (26, 10, 650): 'No Problem',
#  (26, 10, 700): 'No Problem',
#  (26, 10, 750): 'No Problem',
#  (26, 10, 800): 'No Problem',
#  (26, 10, 850): 'No Problem',
#  (26, 10, 900): 'No Problem',
#  (26, 10, 950): 'No Problem',
#  (26, 10, 1000): 'No Problem',
#  (26, 20, 50): 'No Problem',
#  (26, 20, 100): 'No Problem',
#  (26, 20, 150): 'No Problem',
#  (26, 20, 200): 'No Problem',
#  (26, 20, 250): 'No Problem',
#  (26, 20, 300): 'No Problem',
#  (26, 20, 350): 'No Problem',
#  (26, 20, 400): 'No Problem',
#  (26, 20, 450): 'No Problem',
#  (26, 20, 500): 'No Problem',
#  (26, 20, 550): 'No Problem',
#  (26, 20, 600): 'No Problem',
#  (26, 20, 650): 'No Problem',
#  (26, 20, 700): 'No Problem',
#  (26, 20, 750): 'No Problem',
#  (26, 20, 800): 'No Problem',
#  (26, 20, 850): 'No Problem',
#  (26, 20, 900): 'No Problem',
#  (26, 20, 950): 'No Problem',
#  (26, 20, 1000): 'No Problem',
#  (26, 30, 50): 'No Problem',
#  (26, 30, 100): 'No Problem',
#  (26, 30, 150): 'No Problem',
#  (26, 30, 200): 'No Problem',
#  (26, 30, 250): 'No Problem',
#  (26, 30, 300): 'No Problem',
#  (26, 30, 350): 'No Problem',
#  (26, 30, 400): 'No Problem',
#  (26, 30, 450): 'No Problem',
#  (26, 30, 500): 'No Problem',
#  (26, 30, 550): 'No Problem',
#  (26, 30, 600): 'No Problem',
#  (26, 30, 650): 'No Problem',
#  (26, 30, 700): 'No Problem',
#  (26, 30, 750): 'No Problem',
#  (26, 30, 800): 'No Problem',
#  (26, 30, 850): 'No Problem',
#  (26, 30, 900): 'No Problem',
#  (26, 30, 950): 'No Problem',
#  (26, 30, 1000): 'No Problem',
#  (26, 40, 50): 'No Problem',
#  (26, 40, 100): 'No Problem',
#  (26, 40, 150): 'No Problem',
#  (26, 40, 200): 'No Problem',
#  (26, 40, 250): 'No Problem',
#  (26, 40, 300): 'No Problem',
#  (26, 40, 350): 'No Problem',
#  (26, 40, 400): 'No Problem',
#  (26, 40, 450): 'No Problem',
#  (26, 40, 500): 'No Problem',
#  (26, 40, 550): 'No Problem',
#  (26, 40, 600): 'No Problem',
#  (26, 40, 650): 'No Problem',
#  (26, 40, 700): 'No Problem',
#  (26, 40, 750): 'No Problem',
#  (26, 40, 800): 'No Problem',
#  (26, 40, 850): 'No Problem',
#  (26, 40, 900): 'No Problem',
#  (26, 40, 950): 'No Problem',
#  (26, 40, 1000): 'No Problem',
#  (26, 50, 50): 'No Problem',
#  (26, 50, 100): 'No Problem',
#  (26, 50, 150): 'No Problem',
#  (26, 50, 200): 'No Problem',
#  (26, 50, 250): 'No Problem',
#  (26, 50, 300): 'No Problem',
#  (26, 50, 350): 'No Problem',
#  (26, 50, 400): 'No Problem',
#  (26, 50, 450): 'No Problem',
#  (26, 50, 500): 'No Problem',
#  (26, 50, 550): 'No Problem',
#  (26, 50, 600): 'No Problem',
#  (26, 50, 650): 'Gradient Problem Detected',
#  (26, 60, 50): 'No Problem',
#  (26, 60, 100): 'No Problem',
#  (26, 60, 150): 'No Problem',
#  (26, 60, 200): 'No Problem',
#  (26, 60, 250): 'No Problem',
#  (26, 60, 300): 'No Problem',
#  (26, 60, 350): 'No Problem',
#  (26, 60, 400): 'No Problem',
#  (26, 60, 450): 'No Problem',
#  (26, 60, 500): 'No Problem',
#  (26, 60, 550): 'No Problem',
#  (26, 60, 600): 'No Problem',
#  (26, 60, 650): 'No Problem',
#  (26, 60, 700): 'No Problem',
#  (26, 60, 750): 'No Problem',
#  (26, 60, 800): 'No Problem',
#  (26, 60, 850): 'No Problem',
#  (26, 60, 900): 'No Problem',
#  (26, 60, 950): 'No Problem',
#  (26, 60, 1000): 'No Problem',
#  (26, 70, 50): 'No Problem',
#  (26, 70, 100): 'Gradient Problem Detected',
#  (26, 80, 50): 'No Problem',
#  (26, 80, 100): 'No Problem',
#  (26, 80, 150): 'No Problem',
#  (26, 80, 200): 'No Problem',
#  (26, 80, 250): 'No Problem',
#  (26, 80, 300): 'No Problem',
#  (26, 80, 350): 'No Problem',
#  (26, 80, 400): 'No Problem',
#  (26, 80, 450): 'No Problem',
#  (26, 80, 500): 'No Problem',
#  (26, 80, 550): 'No Problem',
#  (26, 80, 600): 'No Problem',
#  (26, 80, 650): 'Gradient Problem Detected',
#  (26, 90, 50): 'No Problem',
#  (26, 90, 100): 'No Problem',
#  (26, 90, 150): 'No Problem',
#  (26, 90, 200): 'No Problem',
#  (26, 90, 250): 'No Problem',
#  (26, 90, 300): 'No Problem',
#  (26, 90, 350): 'No Problem',
#  (26, 90, 400): 'No Problem',
#  (26, 90, 450): 'No Problem',
#  (26, 90, 500): 'No Problem',
#  (26, 90, 550): 'No Problem',
#  (26, 90, 600): 'No Problem',
#  (26, 90, 650): 'No Problem',
#  (26, 90, 700): 'No Problem',
#  (26, 90, 750): 'No Problem',
#  (26, 90, 800): 'No Problem',
#  (26, 90, 850): 'No Problem',
#  (26, 90, 900): 'No Problem',
#  (26, 90, 950): 'No Problem',
#  (26, 90, 1000): 'No Problem',
#  (36, 10, 50): 'No Problem',
#  (36, 10, 100): 'No Problem',
#  (36, 10, 150): 'No Problem',
#  (36, 10, 200): 'No Problem',
#  (36, 10, 250): 'No Problem',
#  (36, 10, 300): 'No Problem',
#  (36, 10, 350): 'No Problem',
#  (36, 10, 400): 'No Problem',
#  (36, 10, 450): 'No Problem',
#  (36, 10, 500): 'No Problem',
#  (36, 10, 550): 'No Problem',
#  (36, 10, 600): 'No Problem',
#  (36, 10, 650): 'No Problem',
#  (36, 10, 700): 'No Problem',
#  (36, 10, 750): 'No Problem',
#  (36, 10, 800): 'No Problem',
#  (36, 10, 850): 'No Problem',
#  (36, 10, 900): 'No Problem',
#  (36, 10, 950): 'No Problem',
#  (36, 10, 1000): 'No Problem',
#  (36, 20, 50): 'No Problem',
#  (36, 20, 100): 'No Problem',
#  (36, 20, 150): 'No Problem',
#  (36, 20, 200): 'No Problem',
#  (36, 20, 250): 'No Problem',
#  (36, 20, 300): 'No Problem',
#  (36, 20, 350): 'No Problem',
#  (36, 20, 400): 'No Problem',
#  (36, 20, 450): 'No Problem',
#  (36, 20, 500): 'No Problem',
#  (36, 20, 550): 'No Problem',
#  (36, 20, 600): 'No Problem',
#  (36, 20, 650): 'No Problem',
#  (36, 20, 700): 'No Problem',
#  (36, 20, 750): 'No Problem',
#  (36, 20, 800): 'No Problem',
#  (36, 20, 850): 'No Problem',
#  (36, 20, 900): 'No Problem',
#  (36, 20, 950): 'No Problem',
#  (36, 20, 1000): 'No Problem',
#  (36, 30, 50): 'No Problem',
#  (36, 30, 100): 'No Problem',
#  (36, 30, 150): 'No Problem',
#  (36, 30, 200): 'No Problem',
#  (36, 30, 250): 'No Problem',
#  (36, 30, 300): 'No Problem',
#  (36, 30, 350): 'No Problem',
#  (36, 30, 400): 'No Problem',
#  (36, 30, 450): 'No Problem',
#  (36, 30, 500): 'No Problem',
#  (36, 30, 550): 'No Problem',
#  (36, 30, 600): 'No Problem',
#  (36, 30, 650): 'No Problem',
#  (36, 30, 700): 'No Problem',
#  (36, 30, 750): 'No Problem',
#  (36, 30, 800): 'No Problem',
#  (36, 30, 850): 'No Problem',
#  (36, 30, 900): 'No Problem',
#  (36, 30, 950): 'No Problem',
#  (36, 30, 1000): 'No Problem',
#  (36, 40, 50): 'No Problem',
#  (36, 40, 100): 'No Problem',
#  (36, 40, 150): 'No Problem',
#  (36, 40, 200): 'No Problem',
#  (36, 40, 250): 'No Problem',
#  (36, 40, 300): 'No Problem',
#  (36, 40, 350): 'No Problem',
#  (36, 40, 400): 'No Problem',
#  (36, 40, 450): 'No Problem',
#  (36, 40, 500): 'No Problem',
#  (36, 40, 550): 'No Problem',
#  (36, 40, 600): 'No Problem',
#  (36, 40, 650): 'No Problem',
#  (36, 40, 700): 'No Problem',
#  (36, 40, 750): 'No Problem',
#  (36, 40, 800): 'No Problem',
#  (36, 40, 850): 'No Problem',
#  (36, 40, 900): 'No Problem',
#  (36, 40, 950): 'No Problem',
#  (36, 40, 1000): 'No Problem',
#  (36, 50, 50): 'No Problem',
#  (36, 50, 100): 'No Problem',
#  (36, 50, 150): 'No Problem',
#  (36, 50, 200): 'No Problem',
#  (36, 50, 250): 'No Problem',
#  (36, 50, 300): 'No Problem',
#  (36, 50, 350): 'No Problem',
#  (36, 50, 400): 'No Problem',
#  (36, 50, 450): 'No Problem',
#  (36, 50, 500): 'No Problem',
#  (36, 50, 550): 'No Problem',
#  (36, 50, 600): 'No Problem',
#  (36, 50, 650): 'No Problem',
#  (36, 50, 700): 'No Problem',
#  (36, 50, 750): 'No Problem',
#  (36, 50, 800): 'No Problem',
#  (36, 50, 850): 'No Problem',
#  (36, 50, 900): 'No Problem',
#  (36, 50, 950): 'No Problem',
#  (36, 50, 1000): 'No Problem',
#  (36, 60, 50): 'No Problem',
#  (36, 60, 100): 'No Problem',
#  (36, 60, 150): 'No Problem',
#  (36, 60, 200): 'No Problem',
#  (36, 60, 250): 'No Problem',
#  (36, 60, 300): 'No Problem',
#  (36, 60, 350): 'No Problem',
#  (36, 60, 400): 'No Problem',
#  (36, 60, 450): 'No Problem',
#  (36, 60, 500): 'No Problem',
#  (36, 60, 550): 'No Problem',
#  (36, 60, 600): 'No Problem',
#  (36, 60, 650): 'No Problem',
#  (36, 60, 700): 'No Problem',
#  (36, 60, 750): 'No Problem',
#  (36, 60, 800): 'No Problem',
#  (36, 60, 850): 'No Problem',
#  (36, 60, 900): 'No Problem',
#  (36, 60, 950): 'No Problem',
#  (36, 60, 1000): 'No Problem',
#  (36, 70, 50): 'No Problem',
#  (36, 70, 100): 'No Problem',
#  (36, 70, 150): 'No Problem',
#  (36, 70, 200): 'No Problem',
#  (36, 70, 250): 'No Problem',
#  (36, 70, 300): 'No Problem',
#  (36, 70, 350): 'No Problem',
#  (36, 70, 400): 'No Problem',
#  (36, 70, 450): 'No Problem',
#  (36, 70, 500): 'No Problem',
#  (36, 70, 550): 'No Problem',
#  (36, 70, 600): 'No Problem',
#  (36, 70, 650): 'No Problem',
#  (36, 70, 700): 'No Problem',
#  (36, 70, 750): 'No Problem',
#  (36, 70, 800): 'No Problem',
#  (36, 70, 850): 'No Problem',
#  (36, 70, 900): 'No Problem',
#  (36, 70, 950): 'No Problem',
#  (36, 70, 1000): 'No Problem',
#  (36, 80, 50): 'No Problem',
#  (36, 80, 100): 'No Problem',
#  (36, 80, 150): 'No Problem',
#  (36, 80, 200): 'No Problem',
#  (36, 80, 250): 'No Problem',
#  (36, 80, 300): 'No Problem',
#  (36, 80, 350): 'No Problem',
#  (36, 80, 400): 'No Problem',
#  (36, 80, 450): 'No Problem',
#  (36, 80, 500): 'No Problem',
#  (36, 80, 550): 'No Problem',
#  (36, 80, 600): 'No Problem',
#  (36, 80, 650): 'No Problem',
#  (36, 80, 700): 'No Problem',
#  (36, 80, 750): 'No Problem',
#  (36, 80, 800): 'No Problem',
#  (36, 80, 850): 'No Problem',
#  (36, 80, 900): 'No Problem',
#  (36, 80, 950): 'No Problem',
#  (36, 80, 1000): 'No Problem',
#  (36, 90, 50): 'No Problem',
#  (36, 90, 100): 'No Problem',
#  (36, 90, 150): 'No Problem',
#  (36, 90, 200): 'No Problem',
#  (36, 90, 250): 'No Problem',
#  (36, 90, 300): 'No Problem',
#  (36, 90, 350): 'No Problem',
#  (36, 90, 400): 'No Problem',
#  (36, 90, 450): 'No Problem',
#  (36, 90, 500): 'No Problem',
#  (36, 90, 550): 'No Problem',
#  (36, 90, 600): 'No Problem',
#  (36, 90, 650): 'No Problem',
#  (36, 90, 700): 'No Problem',
#  (36, 90, 750): 'No Problem',
#  (36, 90, 800): 'No Problem',
#  (36, 90, 850): 'No Problem',
#  (36, 90, 900): 'No Problem',
#  (36, 90, 950): 'No Problem',
#  (36, 90, 1000): 'No Problem',
#  (46, 10, 50): 'No Problem',
#  (46, 10, 100): 'No Problem',
#  (46, 10, 150): 'No Problem',
#  (46, 10, 200): 'No Problem',
#  (46, 10, 250): 'No Problem',
#  (46, 10, 300): 'No Problem',
#  (46, 10, 350): 'No Problem',
#  (46, 10, 400): 'No Problem',
#  (46, 10, 450): 'No Problem',
#  (46, 10, 500): 'No Problem',
#  (46, 10, 550): 'No Problem',
#  (46, 10, 600): 'No Problem',
#  (46, 10, 650): 'No Problem',
#  (46, 10, 700): 'No Problem',
#  (46, 10, 750): 'No Problem',
#  (46, 10, 800): 'No Problem',
#  (46, 10, 850): 'No Problem',
#  (46, 10, 900): 'No Problem',
#  (46, 10, 950): 'No Problem',
#  (46, 10, 1000): 'No Problem',
#  (46, 20, 50): 'No Problem',
#  (46, 20, 100): 'No Problem',
#  (46, 20, 150): 'No Problem',
#  (46, 20, 200): 'No Problem',
#  (46, 20, 250): 'No Problem',
#  (46, 20, 300): 'No Problem',
#  (46, 20, 350): 'No Problem',
#  (46, 20, 400): 'No Problem',
#  (46, 20, 450): 'No Problem',
#  (46, 20, 500): 'No Problem',
#  (46, 20, 550): 'No Problem',
#  (46, 20, 600): 'No Problem',
#  (46, 20, 650): 'No Problem',
#  (46, 20, 700): 'No Problem',
#  (46, 20, 750): 'No Problem',
#  (46, 20, 800): 'No Problem',
#  (46, 20, 850): 'No Problem',
#  (46, 20, 900): 'No Problem',
#  (46, 20, 950): 'No Problem',
#  (46, 20, 1000): 'No Problem',
#  (46, 30, 50): 'No Problem',
#  (46, 30, 100): 'No Problem',
#  (46, 30, 150): 'No Problem',
#  (46, 30, 200): 'No Problem',
#  (46, 30, 250): 'No Problem',
#  (46, 30, 300): 'No Problem',
#  (46, 30, 350): 'No Problem',
#  (46, 30, 400): 'No Problem',
#  (46, 30, 450): 'No Problem',
#  (46, 30, 500): 'No Problem',
#  (46, 30, 550): 'No Problem',
#  (46, 30, 600): 'No Problem',
#  (46, 30, 650): 'No Problem',
#  (46, 30, 700): 'No Problem',
#  (46, 30, 750): 'No Problem',
#  (46, 30, 800): 'No Problem',
#  (46, 30, 850): 'No Problem',
#  (46, 30, 900): 'No Problem',
#  (46, 30, 950): 'No Problem',
#  (46, 30, 1000): 'No Problem',
#  (46, 40, 50): 'No Problem',
#  (46, 40, 100): 'No Problem',
#  (46, 40, 150): 'No Problem',
#  (46, 40, 200): 'No Problem',
#  (46, 40, 250): 'No Problem',
#  (46, 40, 300): 'No Problem',
#  (46, 40, 350): 'No Problem',
#  (46, 40, 400): 'No Problem',
#  (46, 40, 450): 'No Problem',
#  (46, 40, 500): 'No Problem',
#  (46, 40, 550): 'No Problem',
#  (46, 40, 600): 'No Problem',
#  (46, 40, 650): 'No Problem',
#  (46, 40, 700): 'No Problem',
#  (46, 40, 750): 'No Problem',
#  (46, 40, 800): 'No Problem',
#  (46, 40, 850): 'No Problem',
#  (46, 40, 900): 'No Problem',
#  (46, 40, 950): 'No Problem',
#  (46, 40, 1000): 'No Problem',
#  (46, 50, 50): 'No Problem',
#  (46, 50, 100): 'No Problem',
#  (46, 50, 150): 'No Problem',
#  (46, 50, 200): 'No Problem',
#  (46, 50, 250): 'No Problem',
#  (46, 50, 300): 'No Problem',
#  (46, 50, 350): 'No Problem',
#  (46, 50, 400): 'No Problem',
#  (46, 50, 450): 'No Problem',
#  (46, 50, 500): 'No Problem',
#  (46, 50, 550): 'No Problem',
#  (46, 50, 600): 'No Problem',
#  (46, 50, 650): 'No Problem',
#  (46, 50, 700): 'No Problem',
#  (46, 50, 750): 'No Problem',
#  (46, 50, 800): 'No Problem',
#  (46, 50, 850): 'No Problem',
#  (46, 50, 900): 'No Problem',
#  (46, 50, 950): 'No Problem',
#  (46, 50, 1000): 'No Problem',
#  (46, 60, 50): 'No Problem',
#  (46, 60, 100): 'No Problem',
#  (46, 60, 150): 'No Problem',
#  (46, 60, 200): 'No Problem',
#  (46, 60, 250): 'No Problem',
#  (46, 60, 300): 'No Problem',
#  (46, 60, 350): 'No Problem',
#  (46, 60, 400): 'No Problem',
#  (46, 60, 450): 'No Problem',
#  (46, 60, 500): 'No Problem',
#  (46, 60, 550): 'No Problem',
#  (46, 60, 600): 'No Problem',
#  (46, 60, 650): 'No Problem',
#  (46, 60, 700): 'No Problem',
#  (46, 60, 750): 'No Problem',
#  (46, 60, 800): 'No Problem',
#  (46, 60, 850): 'No Problem',
#  (46, 60, 900): 'No Problem',
#  (46, 60, 950): 'No Problem',
#  (46, 60, 1000): 'No Problem',
#  (46, 70, 50): 'No Problem',
#  (46, 70, 100): 'No Problem',
#  (46, 70, 150): 'No Problem',
#  (46, 70, 200): 'No Problem',
#  (46, 70, 250): 'No Problem',
#  (46, 70, 300): 'No Problem',
#  (46, 70, 350): 'No Problem',
#  (46, 70, 400): 'No Problem',
#  (46, 70, 450): 'No Problem',
#  (46, 70, 500): 'No Problem',
#  (46, 70, 550): 'No Problem',
#  (46, 70, 600): 'No Problem',
#  (46, 70, 650): 'No Problem',
#  (46, 70, 700): 'No Problem',
#  (46, 70, 750): 'No Problem',
#  (46, 70, 800): 'No Problem',
#  (46, 70, 850): 'No Problem',
#  (46, 70, 900): 'No Problem',
#  (46, 70, 950): 'No Problem',
#  (46, 70, 1000): 'No Problem',
#  (46, 80, 50): 'No Problem',
#  (46, 80, 100): 'No Problem',
#  (46, 80, 150): 'No Problem',
#  (46, 80, 200): 'No Problem',
#  (46, 80, 250): 'No Problem',
#  (46, 80, 300): 'No Problem',
#  (46, 80, 350): 'Gradient Problem Detected',
#  (46, 90, 50): 'No Problem',
#  (46, 90, 100): 'No Problem',
#  (46, 90, 150): 'No Problem',
#  (46, 90, 200): 'No Problem',
#  (46, 90, 250): 'No Problem',
#  (46, 90, 300): 'No Problem',
#  (46, 90, 350): 'No Problem',
#  (46, 90, 400): 'No Problem',
#  (46, 90, 450): 'No Problem',
#  (46, 90, 500): 'No Problem',
#  (46, 90, 550): 'No Problem',
#  (46, 90, 600): 'No Problem',
#  (46, 90, 650): 'No Problem',
#  (46, 90, 700): 'No Problem',
#  (46, 90, 750): 'No Problem',
#  (46, 90, 800): 'No Problem',
#  (46, 90, 850): 'No Problem',
#  (46, 90, 900): 'No Problem',
#  (46, 90, 950): 'No Problem',
#  (46, 90, 1000): 'No Problem',
#  (56, 10, 50): 'No Problem',
#  (56, 10, 100): 'No Problem',
#  (56, 10, 150): 'No Problem',
#  (56, 10, 200): 'No Problem',
#  (56, 10, 250): 'No Problem',
#  (56, 10, 300): 'No Problem',
#  (56, 10, 350): 'No Problem',
#  (56, 10, 400): 'No Problem',
#  (56, 10, 450): 'No Problem',
#  (56, 10, 500): 'No Problem',
#  (56, 10, 550): 'No Problem',
#  (56, 10, 600): 'No Problem',
#  (56, 10, 650): 'No Problem',
#  (56, 10, 700): 'No Problem',
#  (56, 10, 750): 'No Problem',
#  (56, 10, 800): 'No Problem',
#  (56, 10, 850): 'No Problem',
#  (56, 10, 900): 'No Problem',
#  (56, 10, 950): 'No Problem',
#  (56, 10, 1000): 'No Problem',
#  (56, 20, 50): 'No Problem',
#  (56, 20, 100): 'No Problem',
#  (56, 20, 150): 'No Problem',
#  (56, 20, 200): 'No Problem',
#  (56, 20, 250): 'No Problem',
#  (56, 20, 300): 'No Problem',
#  (56, 20, 350): 'No Problem',
#  (56, 20, 400): 'No Problem',
#  (56, 20, 450): 'No Problem',
#  (56, 20, 500): 'No Problem',
#  (56, 20, 550): 'No Problem',
#  (56, 20, 600): 'No Problem',
#  (56, 20, 650): 'No Problem',
#  (56, 20, 700): 'No Problem',
#  (56, 20, 750): 'No Problem',
#  (56, 20, 800): 'No Problem',
#  (56, 20, 850): 'No Problem',
#  (56, 20, 900): 'No Problem',
#  (56, 20, 950): 'No Problem',
#  (56, 20, 1000): 'No Problem',
#  (56, 30, 50): 'No Problem',
#  (56, 30, 100): 'No Problem',
#  (56, 30, 150): 'No Problem',
#  (56, 30, 200): 'No Problem',
#  (56, 30, 250): 'No Problem',
#  (56, 30, 300): 'No Problem',
#  (56, 30, 350): 'No Problem',
#  (56, 30, 400): 'No Problem',
#  (56, 30, 450): 'No Problem',
#  (56, 30, 500): 'No Problem',
#  (56, 30, 550): 'No Problem',
#  (56, 30, 600): 'No Problem',
#  (56, 30, 650): 'No Problem',
#  (56, 30, 700): 'No Problem',
#  (56, 30, 750): 'No Problem',
#  (56, 30, 800): 'No Problem',
#  (56, 30, 850): 'No Problem',
#  (56, 30, 900): 'No Problem',
#  (56, 30, 950): 'No Problem',
#  (56, 30, 1000): 'No Problem',
#  (56, 40, 50): 'No Problem',
#  (56, 40, 100): 'No Problem',
#  (56, 40, 150): 'No Problem',
#  (56, 40, 200): 'No Problem',
#  (56, 40, 250): 'Gradient Problem Detected',
#  (56, 50, 50): 'No Problem',
#  (56, 50, 100): 'No Problem',
#  (56, 50, 150): 'No Problem',
#  (56, 50, 200): 'No Problem',
#  (56, 50, 250): 'No Problem',
#  (56, 50, 300): 'No Problem',
#  (56, 50, 350): 'No Problem',
#  (56, 50, 400): 'No Problem',
#  (56, 50, 450): 'No Problem',
#  (56, 50, 500): 'No Problem',
#  (56, 50, 550): 'No Problem',
#  (56, 50, 600): 'No Problem',
#  (56, 50, 650): 'No Problem',
#  (56, 50, 700): 'No Problem',
#  (56, 50, 750): 'No Problem',
#  (56, 50, 800): 'Gradient Problem Detected',
#  (56, 60, 50): 'No Problem',
#  (56, 60, 100): 'No Problem',
#  (56, 60, 150): 'No Problem',
#  (56, 60, 200): 'No Problem',
#  (56, 60, 250): 'No Problem',
#  (56, 60, 300): 'No Problem',
#  (56, 60, 350): 'No Problem',
#  (56, 60, 400): 'No Problem',
#  (56, 60, 450): 'No Problem',
#  (56, 60, 500): 'No Problem',
#  (56, 60, 550): 'No Problem',
#  (56, 60, 600): 'No Problem',
#  (56, 60, 650): 'No Problem',
#  (56, 60, 700): 'No Problem',
#  (56, 60, 750): 'No Problem',
#  (56, 60, 800): 'No Problem',
#  (56, 60, 850): 'No Problem',
#  (56, 60, 900): 'No Problem',
#  (56, 60, 950): 'No Problem',
#  (56, 60, 1000): 'No Problem',
#  (56, 70, 50): 'No Problem',
#  (56, 70, 100): 'No Problem',
#  (56, 70, 150): 'No Problem',
#  (56, 70, 200): 'No Problem',
#  (56, 70, 250): 'No Problem',
#  (56, 70, 300): 'No Problem',
#  (56, 70, 350): 'No Problem',
#  (56, 70, 400): 'No Problem',
#  (56, 70, 450): 'No Problem',
#  (56, 70, 500): 'No Problem',
#  (56, 70, 550): 'No Problem',
#  (56, 70, 600): 'No Problem',
#  (56, 70, 650): 'No Problem',
#  (56, 70, 700): 'No Problem',
#  (56, 70, 750): 'No Problem',
#  (56, 70, 800): 'No Problem',
#  (56, 70, 850): 'No Problem',
#  (56, 70, 900): 'No Problem',
#  (56, 70, 950): 'No Problem',
#  (56, 70, 1000): 'No Problem',
#  (56, 80, 50): 'No Problem',
#  (56, 80, 100): 'No Problem',
#  (56, 80, 150): 'No Problem',
#  (56, 80, 200): 'No Problem',
#  (56, 80, 250): 'No Problem',
#  (56, 80, 300): 'No Problem',
#  (56, 80, 350): 'No Problem',
#  (56, 80, 400): 'No Problem',
#  (56, 80, 450): 'No Problem',
#  (56, 80, 500): 'No Problem',
#  (56, 80, 550): 'No Problem',
#  (56, 80, 600): 'No Problem',
#  (56, 80, 650): 'No Problem',
#  (56, 80, 700): 'No Problem',
#  (56, 80, 750): 'No Problem',
#  (56, 80, 800): 'No Problem',
#  (56, 80, 850): 'No Problem',
#  (56, 80, 900): 'No Problem',
#  (56, 80, 950): 'No Problem',
#  (56, 80, 1000): 'No Problem',
#  (56, 90, 50): 'No Problem',
#  (56, 90, 100): 'No Problem',
#  (56, 90, 150): 'No Problem',
#  (56, 90, 200): 'No Problem',
#  (56, 90, 250): 'No Problem',
#  (56, 90, 300): 'No Problem',
#  (56, 90, 350): 'No Problem',
#  (56, 90, 400): 'No Problem',
#  (56, 90, 450): 'No Problem',
#  (56, 90, 500): 'No Problem',
#  (56, 90, 550): 'No Problem',
#  (56, 90, 600): 'No Problem',
#  (56, 90, 650): 'No Problem',
#  (56, 90, 700): 'No Problem',
#  (56, 90, 750): 'No Problem',
#  (56, 90, 800): 'No Problem',
#  (56, 90, 850): 'No Problem',
#  (56, 90, 900): 'No Problem',
#  (56, 90, 950): 'No Problem',
#  (56, 90, 1000): 'No Problem',
#  (66, 10, 50): 'No Problem',
#  (66, 10, 100): 'No Problem',
#  (66, 10, 150): 'No Problem',
#  (66, 10, 200): 'No Problem',
#  (66, 10, 250): 'No Problem',
#  (66, 10, 300): 'No Problem',
#  (66, 10, 350): 'No Problem',
#  (66, 10, 400): 'No Problem',
#  (66, 10, 450): 'No Problem',
#  (66, 10, 500): 'No Problem',
#  (66, 10, 550): 'No Problem',
#  (66, 10, 600): 'No Problem',
#  (66, 10, 650): 'No Problem',
#  (66, 10, 700): 'No Problem',
#  (66, 10, 750): 'No Problem',
#  (66, 10, 800): 'No Problem',
#  (66, 10, 850): 'No Problem',
#  (66, 10, 900): 'No Problem',
#  (66, 10, 950): 'No Problem',
#  (66, 10, 1000): 'No Problem',
#  (66, 20, 50): 'No Problem',
#  (66, 20, 100): 'No Problem',
#  (66, 20, 150): 'No Problem',
#  (66, 20, 200): 'No Problem',
#  (66, 20, 250): 'No Problem',
#  (66, 20, 300): 'No Problem',
#  (66, 20, 350): 'No Problem',
#  (66, 20, 400): 'No Problem',
#  (66, 20, 450): 'No Problem',
#  (66, 20, 500): 'No Problem',
#  (66, 20, 550): 'No Problem',
#  (66, 20, 600): 'No Problem',
#  (66, 20, 650): 'No Problem',
#  (66, 20, 700): 'No Problem',
#  (66, 20, 750): 'No Problem',
#  (66, 20, 800): 'No Problem',
#  (66, 20, 850): 'No Problem',
#  (66, 20, 900): 'No Problem',
#  (66, 20, 950): 'No Problem',
#  (66, 20, 1000): 'No Problem',
#  (66, 30, 50): 'No Problem',
#  (66, 30, 100): 'No Problem',
#  (66, 30, 150): 'No Problem',
#  (66, 30, 200): 'No Problem',
#  (66, 30, 250): 'No Problem',
#  (66, 30, 300): 'No Problem',
#  (66, 30, 350): 'No Problem',
#  (66, 30, 400): 'No Problem',
#  (66, 30, 450): 'No Problem',
#  (66, 30, 500): 'No Problem',
#  (66, 30, 550): 'No Problem',
#  (66, 30, 600): 'No Problem',
#  (66, 30, 650): 'No Problem',
#  (66, 30, 700): 'No Problem',
#  (66, 30, 750): 'Gradient Problem Detected',
#  (66, 40, 50): 'No Problem',
#  (66, 40, 100): 'No Problem',
#  (66, 40, 150): 'No Problem',
#  (66, 40, 200): 'No Problem',
#  (66, 40, 250): 'No Problem',
#  (66, 40, 300): 'No Problem',
#  (66, 40, 350): 'No Problem',
#  (66, 40, 400): 'No Problem',
#  (66, 40, 450): 'No Problem',
#  (66, 40, 500): 'Gradient Problem Detected',
#  (66, 50, 50): 'No Problem',
#  (66, 50, 100): 'No Problem',
#  (66, 50, 150): 'No Problem',
#  (66, 50, 200): 'No Problem',
#  (66, 50, 250): 'No Problem',
#  (66, 50, 300): 'No Problem',
#  (66, 50, 350): 'No Problem',
#  (66, 50, 400): 'No Problem',
#  (66, 50, 450): 'No Problem',
#  (66, 50, 500): 'No Problem',
#  (66, 50, 550): 'No Problem',
#  (66, 50, 600): 'No Problem',
#  (66, 50, 650): 'No Problem',
#  (66, 50, 700): 'No Problem',
#  (66, 50, 750): 'No Problem',
#  (66, 50, 800): 'No Problem',
#  (66, 50, 850): 'No Problem',
#  (66, 50, 900): 'No Problem',
#  (66, 50, 950): 'No Problem',
#  (66, 50, 1000): 'No Problem',
#  (66, 60, 50): 'No Problem',
#  (66, 60, 100): 'No Problem',
#  (66, 60, 150): 'No Problem',
#  (66, 60, 200): 'No Problem',
#  (66, 60, 250): 'No Problem',
#  (66, 60, 300): 'No Problem',
#  (66, 60, 350): 'No Problem',
#  (66, 60, 400): 'No Problem',
#  (66, 60, 450): 'No Problem',
#  (66, 60, 500): 'No Problem',
#  (66, 60, 550): 'No Problem',
#  (66, 60, 600): 'No Problem',
#  (66, 60, 650): 'No Problem',
#  (66, 60, 700): 'No Problem',
#  (66, 60, 750): 'No Problem',
#  (66, 60, 800): 'No Problem',
#  (66, 60, 850): 'No Problem',
#  (66, 60, 900): 'No Problem',
#  (66, 60, 950): 'No Problem',
#  (66, 60, 1000): 'No Problem',
#  (66, 70, 50): 'No Problem',
#  (66, 70, 100): 'No Problem',
#  (66, 70, 150): 'No Problem',
#  (66, 70, 200): 'No Problem',
#  (66, 70, 250): 'No Problem',
#  (66, 70, 300): 'No Problem',
#  (66, 70, 350): 'No Problem',
#  (66, 70, 400): 'No Problem',
#  (66, 70, 450): 'No Problem',
#  (66, 70, 500): 'No Problem',
#  (66, 70, 550): 'No Problem',
#  (66, 70, 600): 'No Problem',
#  (66, 70, 650): 'No Problem',
#  (66, 70, 700): 'No Problem',
#  (66, 70, 750): 'No Problem',
#  (66, 70, 800): 'No Problem',
#  (66, 70, 850): 'No Problem',
#  (66, 70, 900): 'No Problem',
#  (66, 70, 950): 'No Problem',
#  (66, 70, 1000): 'No Problem',
#  (66, 80, 50): 'No Problem',
#  (66, 80, 100): 'No Problem',
#  (66, 80, 150): 'No Problem',
#  (66, 80, 200): 'No Problem',
#  (66, 80, 250): 'No Problem',
#  (66, 80, 300): 'No Problem',
#  (66, 80, 350): 'No Problem',
#  (66, 80, 400): 'No Problem',
#  (66, 80, 450): 'No Problem',
#  (66, 80, 500): 'No Problem',
#  (66, 80, 550): 'No Problem',
#  (66, 80, 600): 'No Problem',
#  (66, 80, 650): 'No Problem',
#  (66, 80, 700): 'No Problem',
#  (66, 80, 750): 'No Problem',
#  (66, 80, 800): 'No Problem',
#  (66, 80, 850): 'No Problem',
#  (66, 80, 900): 'No Problem',
#  (66, 80, 950): 'No Problem',
#  (66, 80, 1000): 'No Problem',
#  (66, 90, 50): 'No Problem',
#  (66, 90, 100): 'No Problem',
#  (66, 90, 150): 'No Problem',
#  (66, 90, 200): 'Gradient Problem Detected',
#  (76, 10, 50): 'No Problem',
#  (76, 10, 100): 'No Problem',
#  (76, 10, 150): 'No Problem',
#  (76, 10, 200): 'No Problem',
#  (76, 10, 250): 'No Problem',
#  (76, 10, 300): 'No Problem',
#  (76, 10, 350): 'No Problem',
#  (76, 10, 400): 'No Problem',
#  (76, 10, 450): 'No Problem',
#  (76, 10, 500): 'No Problem',
#  (76, 10, 550): 'No Problem',
#  (76, 10, 600): 'No Problem',
#  (76, 10, 650): 'No Problem',
#  (76, 10, 700): 'No Problem',
#  (76, 10, 750): 'No Problem',
#  (76, 10, 800): 'No Problem',
#  ...}

# %% [markdown]
# 결과값 dataframe 만들기

# %%
import pandas as pd

data = {
    'Batch Size': [key[0] for key in experiment_results.keys()],
    'Hidden Size': [key[1] for key in experiment_results.keys()],
    'Seq Length': [key[2] for key in experiment_results.keys()],
    'Gradient Problem': list(experiment_results.values())
}


experiment_df = pd.DataFrame(data)

experiment_df.to_pickle("df_lstm.pkl")

# %% [markdown]
# 비율구하기

# %%
frequency = experiment_df['Gradient Problem'].value_counts()

total_count = len(experiment_df)

proportions = frequency / total_count


print(proportions)
print(total_count)
# Out:
# Gradient Problem
# No Problem                   0.972938
# Gradient Problem Detected    0.027062
# Name: count, dtype: float64
# 6984

# %% [markdown]
# 만약 두번째에 실행시 위의 학습과정을 거치지 말고 아래 데이터 프레임을 받아와서 바로 활용 (위의 학습과정이 매우 오래걸림), 구글 드라이브에 데이터프레임 공유

# %%
import pandas as pd
experiment_df = pd.read_pickle("C:/Users/galax/Downloads/df_lstm.pkl")

# %% [markdown]
# 그래프 시각화

# %% [markdown]
# 로지스틱 회귀분석 진행

# %%
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler


experiment_df['Gradient Problem'] = experiment_df['Gradient Problem'].apply(lambda x: 0 if x == 'No Problem' else 1)


X = experiment_df[['Batch Size', 'Hidden Size', 'Seq Length']]
y = experiment_df['Gradient Problem']


X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.2, random_state=0)


scaler = StandardScaler()
X_train_scaled = scaler.fit_transform(X_train)
X_test_scaled = scaler.transform(X_test)


model = LogisticRegression()
model.fit(X_train_scaled, y_train)


predictions = model.predict(X_test_scaled)
print(classification_report(y_test, predictions))
print(confusion_matrix(y_test, predictions))


print("Model Coefficients:", model.coef_)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.98      1.00      0.99      1371
#            1       0.00      0.00      0.00        26
#
#     accuracy                           0.98      1397
#    macro avg       0.49      0.50      0.50      1397
# weighted avg       0.96      0.98      0.97      1397
#
# [[1371    0]
#  [  26    0]]
# Model Coefficients: [[ 0.17916104  0.05760315 -0.12224161]]
# c:\Users\galax\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\galax\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\galax\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# 새로운 값 넣어서 예측해보기

# %%
new_batch_size = int(input('Input new_batch_size : '))
new_hidden_size = int(input('Input new_hidden_size : ')) 
new_seq_length = int(input('Input new_seq_length :'))

new_data = [[new_batch_size, new_hidden_size, new_seq_length]]


new_data_scaled = scaler.transform(new_data)  
prediction = model.predict(new_data_scaled)
predicted_status = "No Problem" if prediction[0] == 0 else "Gradient Problem Detected"
print(predicted_status)
# Out:
# No Problem
# c:\Users\galax\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(
